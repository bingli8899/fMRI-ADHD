# %%
import sys
import os 

rootfolder = "/Users/bingli/Documents/GitHub/fMRI-AHDH" 
sys.path.append(os.path.join(rootfolder))

from src.data.data_loader import load_data 
import src.utility.ut_general as ut_general

datafolder = os.path.join(rootfolder, "data")

# %% [markdown]
# Some quick check for both train and test dataset

# %%
# Load trainning data: 
train_data_dic = load_data(datafolder, filetype = "train") 
train_quant = train_data_dic["train_quant"]
train_outcome = train_data_dic["train_outcome"]
train_cate = train_data_dic["train_cate"]
train_fmri = train_data_dic["train_fmri"]

# %%
# Load test data: 
test_data_dic = load_data(datafolder, filetype = "test")
test_quant = test_data_dic["test_quant"]
test_cate = test_data_dic["test_cate"]
test_fmri = test_data_dic["test_fmri"]

# %%
print(train_fmri.shape) 
print(train_fmri.head)
# Out:
# (1213, 19901)
# <bound method NDFrame.head of      participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0      70z8Q2xdTXM3          0.093473          0.146902          0.067893
# 1      WHWymJu6zNZi          0.029580          0.179323          0.112933
# 2      4PAQp1M6EyAo         -0.051580          0.139734          0.068295
# 3      obEacy4Of68I          0.016273          0.204702          0.115980
# 4      s7WzzDcmDOhF          0.065771          0.098714          0.097604
# ...             ...               ...               ...               ...
# 1208   kTurROKp5YHQ          0.022932          0.024830         -0.006514
# 1209   FCRyMz9O6yCq          0.047078          0.135955          0.144366
# 1210   vm2P1hmAY1hl          0.094541          0.145280          0.061964
# 1211   OFxvN8lnw21w         -0.001533          0.128562          0.045000
# 1212   9gpepMI9sj5q         -0.115224          0.147713          0.083183
#
#       0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0             0.015141          0.070221          0.063997          0.055382
# 1             0.038291          0.104899          0.064250          0.008488
# 2             0.046991          0.111085          0.026978          0.151377
# 3             0.043103          0.056431          0.057615          0.055773
# 4             0.112988          0.071139          0.085607          0.019392
# ...                ...               ...               ...               ...
# 1208          0.021070          0.093365          0.083369          0.010991
# 1209          0.054938          0.065760          0.113550          0.032621
# 1210          0.030562          0.078278          0.105857          0.043984
# 1211         -0.008742          0.003673          0.086494          0.090101
# 1212          0.054649          0.034871         -0.046438         -0.006836
#
#       0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# 0            -0.035335          0.068583  ...              0.003404
# 1             0.077505         -0.004750  ...             -0.008409
# 2             0.021198          0.083721  ...              0.053245
# 3             0.075030          0.001033  ...             -0.023918
# 4            -0.036403         -0.020375  ...              0.066439
# ...                ...               ...  ...                   ...
# 1208          0.035838          0.023909  ...              0.060060
# 1209          0.025349          0.011848  ...              0.021318
# 1210          0.039145          0.032024  ...             -0.052990
# 1211         -0.037449         -0.026334  ...              0.024479
# 1212          0.058453          0.044953  ...              0.063316
#
#       195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0                -0.010359             -0.050968             -0.014365
# 1                -0.008479              0.020891              0.017754
# 2                -0.028003              0.028773              0.024556
# 3                -0.005356              0.018607              0.016193
# 4                -0.076680             -0.047530             -0.031443
# ...                    ...                   ...                   ...
# 1208             -0.003911             -0.016413              0.089110
# 1209              0.020141             -0.020920              0.030450
# 1210             -0.002118             -0.038452              0.066608
# 1211             -0.036995             -0.061617             -0.001699
# 1212             -0.001991              0.044733              0.022353
#
#       196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0                 0.128066              0.112646             -0.058980
# 1                 0.094040              0.035141              0.032537
# 2                 0.166343              0.058925              0.035485
# 3                 0.072955              0.130135              0.056120
# 4                 0.221213              0.007343              0.005763
# ...                    ...                   ...                   ...
# 1208              0.118587             -0.060868              0.124443
# 1209              0.190241              0.026461             -0.011593
# 1210              0.143446              0.051221              0.127495
# 1211              0.106568              0.023427             -0.003520
# 1212             -0.070094              0.046588             -0.036669
#
#       197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0                 0.028228              0.133582              0.143372
# 1                 0.075007              0.115350              0.138200
# 2                 0.063661              0.042862              0.162162
# 3                 0.084784              0.114148              0.190584
# 4                 0.083820              0.079582              0.067269
# ...                    ...                   ...                   ...
# 1208              0.028510              0.113064              0.103809
# 1209              0.139483             -0.064480              0.070354
# 1210              0.106242             -0.036065              0.151341
# 1211              0.174972              0.041198              0.152029
# 1212              0.020141              0.022989              0.191386
#
# [1213 rows x 19901 columns]>

# %% [markdown]
# There are 1213 patients. 19901 - 1 columns shows the  functional connectivity values between pairs of brain regions. Based on my understanding, there are multiple regions in brains. Each column in the dataset represents how those regions connects with each other. Positive value means the brain regions are functionally connected (they activate together). Negative regions means brain regions are anti-correlated regions (one activates while the other deactivates). Near-zero values means no strong functional relationship.

# %%
train_fmri_summary = train_fmri.describe()

# %%
print(train_fmri_summary.index) # Stats types in df.describe() 
for row in train_fmri_summary.index[1:]: # skip counts since it is always 1213
    ut_general.check_connect_in_summary_stats(train_fmri_summary, row)
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')
# Columns with highest connectivity mean values:  26throw_129thcolumn     0.326986
# 14throw_15thcolumn      0.232287
# 115throw_117thcolumn    0.218824
# 18throw_121thcolumn     0.212151
# 96throw_194thcolumn     0.206330
# 1throw_103thcolumn      0.205470
# 73throw_182thcolumn     0.202919
# 120throw_121thcolumn    0.173731
# 19throw_122thcolumn     0.173404
# 81throw_186thcolumn     0.165437
# Name: mean, dtype: float64
# Columns with lowest connectivity mean values:  1throw_7thcolumn       -0.031934
# 19throw_112thcolumn    -0.031539
# 73throw_193thcolumn    -0.027431
# 13throw_122thcolumn    -0.026618
# 112throw_122thcolumn   -0.025405
# 151throw_183thcolumn   -0.025171
# 103throw_106thcolumn   -0.024972
# 1throw_6thcolumn       -0.024692
# 50throw_162thcolumn    -0.024393
# 61throw_86thcolumn     -0.024043
# Name: mean, dtype: float64
# Columns with highest connectivity std values:  55throw_143thcolumn     0.098153
# 159throw_177thcolumn    0.094194
# 52throw_54thcolumn      0.089608
# 52throw_53thcolumn      0.089535
# 52throw_162thcolumn     0.089375
# 26throw_129thcolumn     0.087534
# 65throw_169thcolumn     0.086925
# 160throw_162thcolumn    0.085941
# 80throw_159thcolumn     0.084833
# 54throw_160thcolumn     0.083914
# Name: std, dtype: float64
# Columns with lowest connectivity std values:  9throw_74thcolumn      0.024347
# 11throw_74thcolumn     0.024748
# 9throw_172thcolumn     0.024910
# 5throw_188thcolumn     0.024984
# 26throw_74thcolumn     0.025092
# 5throw_74thcolumn      0.025146
# 9throw_175thcolumn     0.025335
# 5throw_172thcolumn     0.025374
# 74throw_129thcolumn    0.025443
# 9throw_164thcolumn     0.025458
# Name: std, dtype: float64
# Columns with highest connectivity min values:  26throw_129thcolumn     0.012173
# 72throw_138thcolumn    -0.006716
# 0throw_100thcolumn     -0.008782
# 18throw_121thcolumn    -0.010498
# 5throw_105thcolumn     -0.013491
# 164throw_172thcolumn   -0.024087
# 9throw_108thcolumn     -0.026781
# 13throw_35thcolumn     -0.030264
# 165throw_173thcolumn   -0.031601
# 25throw_39thcolumn     -0.033766
# Name: min, dtype: float64
# Columns with lowest connectivity min values:  161throw_190thcolumn   -0.376804
# 54throw_143thcolumn    -0.374367
# 124throw_143thcolumn   -0.343080
# 22throw_125thcolumn    -0.341924
# 55throw_158thcolumn    -0.329880
# 3throw_102thcolumn     -0.317143
# 143throw_153thcolumn   -0.314179
# 17throw_134thcolumn    -0.314031
# 153throw_187thcolumn   -0.312696
# 41throw_143thcolumn    -0.311705
# Name: min, dtype: float64
# Columns with highest connectivity 25% values:  26throw_129thcolumn     0.269545
# 14throw_15thcolumn      0.182693
# 115throw_117thcolumn    0.169057
# 18throw_121thcolumn     0.163037
# 96throw_194thcolumn     0.162962
# 73throw_182thcolumn     0.159590
# 1throw_103thcolumn      0.152755
# 81throw_186thcolumn     0.129199
# 120throw_121thcolumn    0.127753
# 19throw_122thcolumn     0.126766
# Name: 25%, dtype: float64
# Columns with lowest connectivity 25% values:  50throw_162thcolumn    -0.070307
# 1throw_7thcolumn       -0.061715
# 52throw_157thcolumn    -0.060859
# 19throw_112thcolumn    -0.059846
# 41throw_53thcolumn     -0.058384
# 41throw_50thcolumn     -0.057762
# 55throw_161thcolumn    -0.057640
# 55throw_169thcolumn    -0.057601
# 48throw_53thcolumn     -0.057082
# 114throw_143thcolumn   -0.056823
# Name: 25%, dtype: float64
# Columns with highest connectivity 50% values:  26throw_129thcolumn     0.323542
# 14throw_15thcolumn      0.228489
# 115throw_117thcolumn    0.213965
# 1throw_103thcolumn      0.205619
# 18throw_121thcolumn     0.205221
# 73throw_182thcolumn     0.203468
# 96throw_194thcolumn     0.201029
# 19throw_122thcolumn     0.169137
# 120throw_121thcolumn    0.168942
# 2throw_102thcolumn      0.163598
# Name: 50%, dtype: float64
# Columns with lowest connectivity 50% values:  1throw_7thcolumn       -0.031022
# 19throw_112thcolumn    -0.030945
# 73throw_193thcolumn    -0.026486
# 1throw_6thcolumn       -0.026418
# 103throw_106thcolumn   -0.026014
# 13throw_122thcolumn    -0.025713
# 151throw_183thcolumn   -0.025195
# 50throw_162thcolumn    -0.024671
# 112throw_122thcolumn   -0.024618
# 61throw_86thcolumn     -0.023261
# Name: 50%, dtype: float64
# Columns with highest connectivity 75% values:  26throw_129thcolumn     0.375756
# 14throw_15thcolumn      0.277368
# 115throw_117thcolumn    0.262253
# 18throw_121thcolumn     0.258235
# 1throw_103thcolumn      0.256553
# 73throw_182thcolumn     0.243925
# 96throw_194thcolumn     0.240668
# 52throw_53thcolumn      0.218288
# 19throw_122thcolumn     0.217969
# 51throw_156thcolumn     0.216501
# Name: 75%, dtype: float64
# Columns with lowest connectivity 75% values:  19throw_112thcolumn    -0.003919
# 87throw_164thcolumn    -0.001810
# 151throw_183thcolumn   -0.001447
# 57throw_188thcolumn    -0.001059
# 57throw_87thcolumn     -0.000717
# 61throw_86thcolumn     -0.000481
# 1throw_7thcolumn       -0.000001
# 73throw_193thcolumn     0.000104
# 26throw_141thcolumn     0.000267
# 46throw_164thcolumn     0.000429
# Name: 75%, dtype: float64
# Columns with highest connectivity max values:  26throw_129thcolumn     0.739065
# 14throw_15thcolumn      0.615033
# 115throw_117thcolumn    0.573135
# 3throw_103thcolumn      0.550239
# 1throw_103thcolumn      0.538463
# 18throw_121thcolumn     0.530609
# 106throw_108thcolumn    0.506494
# 96throw_194thcolumn     0.501372
# 7throw_9thcolumn        0.496367
# 19throw_122thcolumn     0.495310
# Name: max, dtype: float64
# Columns with lowest connectivity max values:  5throw_183thcolumn      0.072857
# 9throw_164thcolumn      0.076854
# 57throw_167thcolumn     0.077707
# 87throw_173thcolumn     0.078541
# 71throw_165thcolumn     0.078920
# 57throw_191thcolumn     0.079424
# 64throw_185thcolumn     0.079617
# 9throw_151thcolumn      0.080299
# 39throw_175thcolumn     0.080308
# 105throw_185thcolumn    0.081449
# Name: max, dtype: float64

# %%
print(test_fmri.shape)
# Out:
# (304, 19901)

# %% [markdown]
# The test dataset has 304 participates.

# %%
test_fmri_summary = test_fmri.describe()

# %%
print(test_fmri_summary.index)
for row in test_fmri_summary.index[1:]:
    ut_general.check_connect_in_summary_stats(test_fmri_summary, row)
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')
# Columns with highest connectivity mean values:  9throw_108thcolumn     0.813280
# 96throw_194thcolumn    0.794468
# 26throw_129thcolumn    0.791315
# 76throw_185thcolumn    0.766086
# 81throw_186thcolumn    0.762251
# 7throw_9thcolumn       0.758799
# 71throw_180thcolumn    0.755745
# 7throw_106thcolumn     0.751816
# 9throw_109thcolumn     0.750291
# 10throw_110thcolumn    0.745769
# Name: mean, dtype: float64
# Columns with lowest connectivity mean values:  76throw_167thcolumn    -0.349344
# 74throw_167thcolumn    -0.331195
# 167throw_185thcolumn   -0.321430
# 78throw_167thcolumn    -0.318888
# 42throw_185thcolumn    -0.316703
# 74throw_140thcolumn    -0.305533
# 74throw_146thcolumn    -0.305525
# 87throw_134thcolumn    -0.304318
# 145throw_185thcolumn   -0.299901
# 74throw_145thcolumn    -0.298863
# Name: mean, dtype: float64
# Columns with highest connectivity std values:  159throw_177thcolumn    0.388346
# 80throw_177thcolumn     0.364669
# 70throw_80thcolumn      0.355468
# 151throw_188thcolumn    0.348113
# 87throw_151thcolumn     0.345223
# 70throw_159thcolumn     0.330899
# 80throw_151thcolumn     0.328980
# 46throw_74thcolumn      0.325584
# 80throw_81thcolumn      0.324171
# 151throw_159thcolumn    0.322572
# Name: std, dtype: float64
# Columns with lowest connectivity std values:  81throw_186thcolumn    0.102224
# 96throw_194thcolumn    0.107179
# 76throw_185thcolumn    0.113259
# 71throw_180thcolumn    0.114278
# 49throw_155thcolumn    0.115414
# 9throw_108thcolumn     0.115746
# 7throw_9thcolumn       0.122042
# 7throw_106thcolumn     0.122346
# 73throw_182thcolumn    0.123689
# 10throw_110thcolumn    0.125653
# Name: std, dtype: float64
# Columns with highest connectivity min values:  11throw_110thcolumn     0.154350
# 6throw_7thcolumn        0.113722
# 7throw_106thcolumn      0.056520
# 25throw_39thcolumn      0.038081
# 7throw_109thcolumn      0.019315
# 26throw_27thcolumn      0.013864
# 42throw_63thcolumn      0.010971
# 21throw_24thcolumn      0.009797
# 9throw_10thcolumn       0.001008
# 106throw_109thcolumn    0.000000
# Name: min, dtype: float64
# Columns with lowest connectivity min values:  159throw_177thcolumn   -0.906309
# 80throw_177thcolumn    -0.884327
# 70throw_159thcolumn    -0.876220
# 70throw_80thcolumn     -0.864944
# 133throw_199thcolumn   -0.845633
# 75throw_115thcolumn    -0.844870
# 75throw_137thcolumn    -0.834742
# 69throw_159thcolumn    -0.832883
# 124throw_149thcolumn   -0.832083
# 92throw_159thcolumn    -0.825791
# Name: min, dtype: float64
# Columns with highest connectivity 25% values:  9throw_108thcolumn      0.775931
# 96throw_194thcolumn     0.770935
# 26throw_129thcolumn     0.760337
# 76throw_185thcolumn     0.741288
# 81throw_186thcolumn     0.715831
# 7throw_106thcolumn      0.712291
# 71throw_180thcolumn     0.709880
# 7throw_9thcolumn        0.709158
# 106throw_108thcolumn    0.705695
# 10throw_110thcolumn     0.695173
# Name: 25%, dtype: float64
# Columns with lowest connectivity 25% values:  76throw_167thcolumn    -0.521993
# 74throw_167thcolumn    -0.503398
# 167throw_185thcolumn   -0.488891
# 42throw_185thcolumn    -0.481697
# 87throw_134thcolumn    -0.480983
# 78throw_167thcolumn    -0.479996
# 74throw_140thcolumn    -0.465379
# 74throw_146thcolumn    -0.465375
# 76throw_165thcolumn    -0.461845
# 88throw_134thcolumn    -0.456661
# Name: 25%, dtype: float64
# Columns with highest connectivity 50% values:  26throw_129thcolumn     0.861720
# 9throw_108thcolumn      0.838737
# 96throw_194thcolumn     0.813870
# 7throw_9thcolumn        0.789370
# 81throw_186thcolumn     0.786050
# 9throw_109thcolumn      0.785991
# 76throw_185thcolumn     0.783898
# 71throw_180thcolumn     0.783675
# 106throw_108thcolumn    0.779564
# 7throw_106thcolumn      0.778456
# Name: 50%, dtype: float64
# Columns with lowest connectivity 50% values:  76throw_167thcolumn    -0.383616
# 167throw_185thcolumn   -0.359059
# 78throw_167thcolumn    -0.353743
# 74throw_167thcolumn    -0.347608
# 74throw_140thcolumn    -0.347430
# 42throw_185thcolumn    -0.342533
# 74throw_146thcolumn    -0.336664
# 88throw_134thcolumn    -0.332962
# 76throw_165thcolumn    -0.326103
# 87throw_134thcolumn    -0.323369
# Name: 50%, dtype: float64
# Columns with highest connectivity 75% values:  26throw_129thcolumn     0.900835
# 9throw_108thcolumn      0.876353
# 96throw_194thcolumn     0.849777
# 9throw_109thcolumn      0.846228
# 7throw_9thcolumn        0.839938
# 106throw_108thcolumn    0.833102
# 71throw_180thcolumn     0.832670
# 81throw_186thcolumn     0.831049
# 7throw_106thcolumn      0.828608
# 10throw_110thcolumn     0.827829
# Name: 75%, dtype: float64
# Columns with lowest connectivity 75% values:  76throw_167thcolumn    -0.205610
# 88throw_133thcolumn    -0.200086
# 42throw_185thcolumn    -0.197312
# 145throw_185thcolumn   -0.188448
# 78throw_167thcolumn    -0.183206
# 74throw_146thcolumn    -0.182352
# 167throw_185thcolumn   -0.180980
# 74throw_167thcolumn    -0.178568
# 74throw_145thcolumn    -0.177037
# 76throw_154thcolumn    -0.176771
# Name: 75%, dtype: float64
# Columns with highest connectivity max values:  16throw_89thcolumn     0.983481
# 29throw_58thcolumn     0.983457
# 48throw_195thcolumn    0.983083
# 21throw_127thcolumn    0.982971
# 26throw_198thcolumn    0.982929
# 89throw_145thcolumn    0.982258
# 37throw_52thcolumn     0.982141
# 59throw_184thcolumn    0.981794
# 29throw_60thcolumn     0.981708
# 39throw_142thcolumn    0.980963
# Name: max, dtype: float64
# Columns with lowest connectivity max values:  57throw_143thcolumn     0.260010
# 91throw_130thcolumn     0.260575
# 111throw_196thcolumn    0.263888
# 19throw_155thcolumn     0.268407
# 108throw_190thcolumn    0.273758
# 102throw_196thcolumn    0.275568
# 32throw_170thcolumn     0.275898
# 107throw_190thcolumn    0.279568
# 32throw_196thcolumn     0.281483
# 164throw_187thcolumn    0.284373
# Name: max, dtype: float64

# %% [markdown]
# I don't understand. Why the range between test and train datasets vary hugely???
#
# This dramatic difference in connectome between train and test datset made me worried if the data of test and train were processed in the same way? It is intereating since even stardard deviation in the test dataset is higher than the train dataset in general.
#
# Maybe both datasets got normalized or got some processed before and they are not processed the same.

# %%
# Let's check a histogram of some potential values in the connectome dataset 

# Randomly select 'proportion' * 19900 * num of participates --> Dataset too large to plot the whole 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def plot_histogram_with_randomly_sampled_N(train_fmri, test_fmri, N):
    
    random_train_fmri = []
    random_test_fmri = []

    # Sample from each column --> Hopefully can make the process quicker :(
    for col in train_fmri.columns[1:]: # (excluding the participant ID if present) 
        random_train_fmri.extend(np.random.choice(train_fmri[col].values, size=N, replace=False))

    for col in test_fmri.columns[1:]: 
        random_test_fmri.extend(np.random.choice(test_fmri[col].values, size=N, replace=False))

    random_train_fmri = np.array(random_train_fmri)
    random_test_fmri = np.array(random_test_fmri)

    # Plot distributions
    plt.figure(figsize=(10, 6))
    sns.histplot(random_train_fmri, bins=50, color="blue", label="Train Sample", kde=True, alpha=0.6)
    sns.histplot(random_test_fmri, bins=50, color="red", label="Test Sample", kde=True, alpha=0.6)
    plt.legend()
    plt.title(f"Distribution of Sampled fMRI Connectivity Values (N: N%)")
    plt.xlabel("Connectivity Strength")
    plt.ylabel("Frequency")
    plt.show()

plot_histogram_with_prop(train_fmri, test_fmri, 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 39
#      36     plt.ylabel("Frequency")
#      37     plt.show()
# ---> 39 plot_histogram_with_prop(train_fmri, test_fmri, 100)
#
# Cell In[7], line 23, in plot_histogram_with_prop(train_fmri, test_fmri, proportion)
#      21 # Sample from each column (excluding the participant ID if present)
#      22 for col in train_fmri.columns[1:]:
# ---> 23     random_train_fmri.extend(np.random.choice(train_fmri[col].values, size=train_sample_size_per_col, replace=False))
#      25 for col in test_fmri.columns[1:]:
#      26     random_test_fmri.extend(np.random.choice(test_fmri[col].values, size=test_sample_size_per_col, replace=False))
#
# File mtrand.pyx:984, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
